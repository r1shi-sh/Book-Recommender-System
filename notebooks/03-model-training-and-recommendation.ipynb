# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import NearestNeighbors
from sklearn.datasets import load_svmlight_file
import joblib
import os 

# --- Configuration ---
RAW_DATA_DIR = "../data/raw/"
PROCESSED_DATA_DIR = "../data/processed/"
MODEL_DIR = "../models/"
OUTPUT_DIR = "../output/"

# --- Create directories if they don't exist ---
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(OUTPUT_DIR, exist_ok=True)

INPUT_MATRIX_FILE = "user_item_rating_matrix.libsvm"
MODEL_FILE = "knn_recommender.pkl"
OUTPUT_RECOMMENDATIONS_FILE = "recommendations_output.csv"

# --- Load Data and Mappings ---
print("Loading processed data and creating mappings...")

# Load the user-item matrix
user_item_matrix, _ = load_svmlight_file(f"{PROCESSED_DATA_DIR}{INPUT_MATRIX_FILE}")

# To get real book titles, we need to recreate the mappings from the preprocessing step
ratings_df = pd.read_csv(f"{RAW_DATA_DIR}Ratings.csv", delimiter=";", low_memory=False, on_bad_lines='skip', encoding='latin-1')
ratings_df.columns = ['UserID', 'ISBN', 'Rating']
books_df = pd.read_csv(f"{RAW_DATA_DIR}Books.csv", delimiter=";", low_memory=False, on_bad_lines='skip', encoding='latin-1')
# Out:
# Loading processed data and creating mappings...

# %%
# --- Train or Load Model ---
print("Initializing Nearest Neighbors model...")
try:
    # Try to load a pre-trained model to save time
    model_knn = joblib.load(f"{MODEL_DIR}{MODEL_FILE}")
    print("Loaded pre-trained model from disk.")
except FileNotFoundError:
    print("No pre-trained model found. Training a new one...")
    # Setup K-Nearest Neighbors model with cosine similarity
    model_knn = NearestNeighbors(metric='cosine', algorithm='brute')
    model_knn.fit(user_item_matrix)
    # Save the newly trained model for future use
    joblib.dump(model_knn, f"{MODEL_DIR}{MODEL_FILE}")
    print(f"Model trained and saved to {MODEL_DIR}{MODEL_FILE}")
# Out:
# Initializing Nearest Neighbors model...
# No pre-trained model found. Training a new one...
# Model trained and saved to ../models/knn_recommender.pkl

# %%
# --- Recommendation Generation ---

def generate_recommendations(user_idx, k_neighbors=10, top_n=5):
    """Generates book recommendations for a single user."""
    
    # Find K nearest neighbors (excluding the user itself)
    distances, indices = model_knn.kneighbors(user_item_matrix[user_idx], n_neighbors=k_neighbors + 1)
    
    # Get neighbor indexes and their similarity scores
    neighbor_indices = indices.flatten()[1:]
    neighbor_similarities = 1 - distances.flatten()[1:]

    # Get the ratings of the neighbors
    neighbor_ratings = user_item_matrix[neighbor_indices].toarray()
    
    # Calculate the weighted average score for each book
    weighted_scores = np.dot(neighbor_similarities, neighbor_ratings)
    
    # Exclude books the user has already rated
    user_rated_books = user_item_matrix[user_idx].toarray().flatten() > 0
    weighted_scores[user_rated_books] = 0
    
    # Get the top N book indexes
    top_book_indices = np.argsort(-weighted_scores)[:top_n]
    
    # Create a list of recommendations
    recommendations = []
    for book_idx in top_book_indices:
        isbn = index_to_book.get(book_idx)
        recommendations.append({
            "User_Index": user_idx,
            "Book_Title": isbn_to_title.get(isbn, "Unknown Title"),
            "Recommendation_Score": weighted_scores[book_idx],
            "ISBN": isbn
        })
    return recommendations

# %%
# --- Generate for All Users and Save ---
print("\nGenerating recommendations for all users...")
all_recommendations = []
num_users = user_item_matrix.shape[0]

# Remove `[:1000]` to run for all users.
for user_idx in range(num_users)[:1000]:
    if user_idx % 100 == 0:
        print(f"Processing user {user_idx}/{num_users}...")
    recs = generate_recommendations(user_idx)
    all_recommendations.extend(recs)

recommendations_df = pd.DataFrame(all_recommendations)

# --- Save Output ---
recommendations_df.to_csv(f"{OUTPUT_DIR}{OUTPUT_RECOMMENDATIONS_FILE}", index=False)
print(f"\nRecommendations saved successfully to {OUTPUT_DIR}{OUTPUT_RECOMMENDATIONS_FILE}")
display(recommendations_df.head(10))
# Out:
# Generating recommendations for all users...
# Processing user 0/105283...
# Processing user 100/105283...
# Processing user 200/105283...
# Processing user 300/105283...
# Processing user 400/105283...
# Processing user 500/105283...
# Processing user 600/105283...
# Processing user 700/105283...
# Processing user 800/105283...
# Processing user 900/105283...
# Processing user 1000/105283...
# Processing user 1100/105283...
# Processing user 1200/105283...
# Processing user 1300/105283...
# Processing user 1400/105283...
# Processing user 1500/105283...
# Processing user 1600/105283...
# Processing user 1700/105283...
# Processing user 1800/105283...
# Processing user 1900/105283...
# Processing user 2000/105283...
# Processing user 2100/105283...
# Processing user 2200/105283...
# Processing user 2300/105283...
# Processing user 2400/105283...
# Processing user 2500/105283...
# Processing user 2600/105283...
# Processing user 2700/105283...
# Processing user 2800/105283...
# Processing user 2900/105283...
# Processing user 3000/105283...
# Processing user 3100/105283...
# Processing user 3200/105283...
# Processing user 3300/105283...
# Processing user 3400/105283...
# Processing user 3500/105283...
# Processing user 3600/105283...
# Processing user 3700/105283...
# Processing user 3800/105283...
# Processing user 3900/105283...
# Processing user 4000/105283...
# Processing user 4100/105283...
# Processing user 4200/105283...
# Processing user 4300/105283...
# Processing user 4400/105283...
# Processing user 4500/105283...
# Processing user 4600/105283...
# Processing user 4700/105283...
# Processing user 4800/105283...
# Processing user 4900/105283...
# Processing user 5000/105283...
# Processing user 5100/105283...
# Processing user 5200/105283...
# Processing user 5300/105283...
# Processing user 5400/105283...
# Processing user 5500/105283...
# Processing user 5600/105283...
# Processing user 5700/105283...
# Processing user 5800/105283...
# Processing user 5900/105283...
# Processing user 6000/105283...
# Processing user 6100/105283...
# Processing user 6200/105283...
# Processing user 6300/105283...
# Processing user 6400/105283...
# Processing user 6500/105283...
# Processing user 6600/105283...
# Processing user 6700/105283...
# Processing user 6800/105283...
# Processing user 6900/105283...
# Processing user 7000/105283...
# Processing user 7100/105283...
# Processing user 7200/105283...
# Processing user 7300/105283...
# Processing user 7400/105283...
# Processing user 7500/105283...
# Processing user 7600/105283...
# Processing user 7700/105283...
# Processing user 7800/105283...
# Processing user 7900/105283...
# Processing user 8000/105283...
# Processing user 8100/105283...
# Processing user 8200/105283...
# Processing user 8300/105283...
# Processing user 8400/105283...
# Processing user 8500/105283...
# Processing user 8600/105283...
# Processing user 8700/105283...
# Processing user 8800/105283...
# Processing user 8900/105283...
# Processing user 9000/105283...
# Processing user 9100/105283...
# Processing user 9200/105283...
# Processing user 9300/105283...
# Processing user 9400/105283...
# Processing user 9500/105283...
# Processing user 9600/105283...
# Processing user 9700/105283...
# Processing user 9800/105283...
# Processing user 9900/105283...
# Processing user 10000/105283...
# Processing user 10100/105283...
# Processing user 10200/105283...
# Processing user 10300/105283...
# Processing user 10400/105283...
# Processing user 10500/105283...
# Processing user 10600/105283...
# Processing user 10700/105283...
# Processing user 10800/105283...
# Processing user 10900/105283...
# Processing user 11000/105283...
# Processing user 11100/105283...
# Processing user 11200/105283...
# Processing user 11300/105283...
# Processing user 11400/105283...
# Processing user 11500/105283...
# Processing user 11600/105283...
# Processing user 11700/105283...
# Processing user 11800/105283...
# Processing user 11900/105283...
# Processing user 12000/105283...
# Processing user 12100/105283...
# Processing user 12200/105283...
# Processing user 12300/105283...
# Processing user 12400/105283...
# Processing user 12500/105283...
# Processing user 12600/105283...
# Processing user 12700/105283...
# Processing user 12800/105283...
# Processing user 12900/105283...
# Processing user 13000/105283...
# Processing user 13100/105283...
# Processing user 13200/105283...
# Processing user 13300/105283...
# Processing user 13400/105283...
# Processing user 13500/105283...
# Processing user 13600/105283...
# Processing user 13700/105283...
# Processing user 13800/105283...
# Processing user 13900/105283...
# Processing user 14000/105283...
# Processing user 14100/105283...
# Processing user 14200/105283...
# Processing user 14300/105283...
# Processing user 14400/105283...
# Processing user 14500/105283...
# Processing user 14600/105283...
# Processing user 14700/105283...
# Processing user 14800/105283...
# Processing user 14900/105283...
# Processing user 15000/105283...
# Processing user 15100/105283...
# Processing user 15200/105283...
# Processing user 15300/105283...
# Processing user 15400/105283...
# Processing user 15500/105283...
# Processing user 15600/105283...
# Processing user 15700/105283...
# Processing user 15800/105283...
# Processing user 15900/105283...
# Processing user 16000/105283...
# Processing user 16100/105283...
# Processing user 16200/105283...
# Processing user 16300/105283...
# Processing user 16400/105283...
# Processing user 16500/105283...
# Processing user 16600/105283...
# Processing user 16700/105283...
# Processing user 16800/105283...
# Processing user 16900/105283...
# Processing user 17000/105283...
# Processing user 17100/105283...
# Processing user 17200/105283...
# Processing user 17300/105283...
# Processing user 17400/105283...
# Processing user 17500/105283...
# Processing user 17600/105283...
# Processing user 17700/105283...
# Processing user 17800/105283...
# Processing user 17900/105283...
# Processing user 18000/105283...
# Processing user 18100/105283...
# Processing user 18200/105283...
# Processing user 18300/105283...
# Processing user 18400/105283...
# Processing user 18500/105283...
# Processing user 18600/105283...
# Processing user 18700/105283...
# Processing user 18800/105283...
# Processing user 18900/105283...
# Processing user 19000/105283...
# Processing user 19100/105283...
# Processing user 19200/105283...
# Processing user 19300/105283...
# Processing user 19400/105283...
# Processing user 19500/105283...
# Processing user 19600/105283...
# Processing user 19700/105283...
# Processing user 19800/105283...
# Processing user 19900/105283...
# Processing user 20000/105283...
# Processing user 20100/105283...
# Processing user 20200/105283...
# Processing user 20300/105283...
# Processing user 20400/105283...
# Processing user 20500/105283...
# Processing user 20600/105283...
# Processing user 20700/105283...
# Processing user 20800/105283...
# Processing user 20900/105283...
# Processing user 21000/105283...
# Processing user 21100/105283...
# Processing user 21200/105283...
# Processing user 21300/105283...
# Processing user 21400/105283...
# Processing user 21500/105283...
# Processing user 21600/105283...
# Processing user 21700/105283...
# Processing user 21800/105283...
# Processing user 21900/105283...
# Processing user 22000/105283...
# Processing user 22100/105283...
# Processing user 22200/105283...
# Processing user 22300/105283...
# Processing user 22400/105283...
# Processing user 22500/105283...
# Processing user 71600/105283...
# Processing user 71700/105283...
# Processing user 71800/105283...
# Processing user 71900/105283...
# Processing user 72000/105283...
# Processing user 72100/105283...
# Processing user 72200/105283...
# Processing user 72300/105283...
# Processing user 72400/105283...
# Processing user 72500/105283...
# Processing user 72600/105283...
# Processing user 72700/105283...
# Processing user 72800/105283...
# Processing user 72900/105283...
# Processing user 73000/105283...
# Processing user 73100/105283...
# Processing user 73200/105283...
# Processing user 73300/105283...
# Processing user 73400/105283...
# Processing user 73500/105283...
# Processing user 73600/105283...
# Processing user 73700/105283...
# Processing user 73800/105283...
# Processing user 73900/105283...
# Processing user 74000/105283...
# Processing user 74100/105283...
# Processing user 74200/105283...
# Processing user 74300/105283...
# Processing user 74400/105283...
# Processing user 74500/105283...
# Processing user 74600/105283...
# Processing user 74700/105283...
# Processing user 74800/105283...
# Processing user 74900/105283...
# Processing user 75000/105283...
# Processing user 75100/105283...
# Processing user 75200/105283...
# Processing user 75300/105283...
# Processing user 75400/105283...
# Processing user 75500/105283...
# Processing user 75600/105283...
# Processing user 75700/105283...
# Processing user 75800/105283...
# Processing user 75900/105283...
# Processing user 76000/105283...
# Processing user 76100/105283...
# Processing user 76200/105283...
# Processing user 76300/105283...
# Processing user 76400/105283...
# Processing user 76500/105283...
# Processing user 76600/105283...
# Processing user 76700/105283...
# Processing user 76800/105283...
# Processing user 76900/105283...
# Processing user 77000/105283...
# Processing user 77100/105283...
# Processing user 77200/105283...
# Processing user 77300/105283...
# Processing user 77400/105283...
# Processing user 77500/105283...
# Processing user 77600/105283...
# Processing user 77700/105283...
# Processing user 77800/105283...
# Processing user 77900/105283...
# Processing user 78000/105283...
# Processing user 78100/105283...
# Processing user 78200/105283...
# Processing user 78300/105283...
# Processing user 78400/105283...
# Processing user 78500/105283...
# Processing user 78600/105283...
# Processing user 78700/105283...
# Processing user 78800/105283...
# Processing user 78900/105283...
# Processing user 79000/105283...
# Processing user 79100/105283...
# Processing user 79200/105283...
# Processing user 79300/105283...
# Processing user 79400/105283...
# Processing user 79500/105283...
# Processing user 79600/105283...
# Processing user 79700/105283...
# Processing user 79800/105283...
# Processing user 79900/105283...
# Processing user 80000/105283...
# Processing user 80100/105283...
# Processing user 80200/105283...
# Processing user 80300/105283...
# Processing user 80400/105283...
# Processing user 80500/105283...
# Processing user 80600/105283...
# Processing user 80700/105283...
# Processing user 80800/105283...
# Processing user 80900/105283...
# Processing user 81000/105283...
# Processing user 81100/105283...
# Processing user 81200/105283...
# Processing user 81300/105283...
# Processing user 81400/105283...
# Processing user 81500/105283...
# Processing user 81600/105283...
# Processing user 81700/105283...
# Processing user 81800/105283...
# Processing user 81900/105283...
# Processing user 82000/105283...
# Processing user 82100/105283...
# Processing user 82200/105283...
# Processing user 82300/105283...
# Processing user 82400/105283...
# Processing user 82500/105283...
# Processing user 82600/105283...
# Processing user 82700/105283...
# Processing user 82800/105283...
# Processing user 82900/105283...
# Processing user 83000/105283...
# Processing user 83100/105283...
# Processing user 83200/105283...
# Processing user 83300/105283...
# Processing user 83400/105283...
# Processing user 83500/105283...
# Processing user 83600/105283...
# Processing user 83700/105283...
# Processing user 96000/105283...
# Processing user 96100/105283...
# Processing user 96200/105283...
# Processing user 96300/105283...
# Processing user 96400/105283...
# Processing user 96500/105283...
# Processing user 96600/105283...
# Processing user 96700/105283...
# Processing user 96800/105283...
# Processing user 96900/105283...
# Processing user 97000/105283...
# Processing user 97100/105283...
# Processing user 97200/105283...
# Processing user 97300/105283...
# Processing user 97400/105283...
# Processing user 97500/105283...
# Processing user 97600/105283...
# Processing user 97700/105283...
# Processing user 97800/105283...
# Processing user 97900/105283...
# Processing user 98000/105283...
# Processing user 98100/105283...
# Processing user 98200/105283...
# Processing user 98300/105283...
# Processing user 98400/105283...
# Processing user 98500/105283...
# Processing user 98600/105283...
# Processing user 98700/105283...
# Processing user 98800/105283...
# Processing user 98900/105283...
# Processing user 99000/105283...
# Processing user 99100/105283...
# Processing user 99200/105283...
# Processing user 99300/105283...
# Processing user 99400/105283...
# Processing user 99500/105283...
# Processing user 99600/105283...
# Processing user 99700/105283...
# Processing user 99800/105283...
# Processing user 99900/105283...
# Processing user 100000/105283...
# Processing user 100100/105283...
# Processing user 100200/105283...
# Processing user 100300/105283...
# Processing user 100400/105283...
# Processing user 100500/105283...
# Processing user 100600/105283...
# Processing user 100700/105283...
# Processing user 100800/105283...
# Processing user 100900/105283...
# Processing user 101000/105283...
# Processing user 101100/105283...
# Processing user 101200/105283...
# Processing user 101300/105283...
# Processing user 101400/105283...
# Processing user 101500/105283...
# Processing user 101600/105283...
# Processing user 101700/105283...
# Processing user 101800/105283...
# Processing user 101900/105283...
# Processing user 102000/105283...
# Processing user 102100/105283...
# Processing user 102200/105283...
# Processing user 102300/105283...
# Processing user 102400/105283...
# Processing user 102500/105283...
# Processing user 102600/105283...
# Processing user 102700/105283...
# Processing user 102800/105283...
# Processing user 102900/105283...
# Processing user 103000/105283...
# Processing user 103100/105283...
# Processing user 103200/105283...
# Processing user 103300/105283...
# Processing user 103400/105283...
# Processing user 103500/105283...
# Processing user 103600/105283...
# Processing user 103700/105283...
# Processing user 103800/105283...
# Processing user 103900/105283...
# Processing user 104000/105283...
# Processing user 104100/105283...
# Processing user 104200/105283...
# Processing user 104300/105283...
# Processing user 104400/105283...
# Processing user 104500/105283...
# Processing user 104600/105283...
# Processing user 104700/105283...
# Processing user 104800/105283...
# Processing user 104900/105283...
# Processing user 105000/105283...
# Processing user 105100/105283...
# Processing user 105200/105283...
#
# Recommendations saved successfully to ../output/recommendations_output.csv
#    User_Index                              Book_Title  Recommendation_Score  \
# 0           0                    Flesh Tones: A Novel                   0.0
# 1           0                      American Primitive                   0.0
# 2           0                Angels Go Naked: A Novel                   0.0
# 3           0  Oliver Twist (Oxford World's Classics)                   0.0
# 4           0                           Unknown Title                   0.0
# 5           1                    Flesh Tones: A Novel                   0.0
# 6           1                      American Primitive                   0.0
# 7           1                Angels Go Naked: A Novel                   0.0
# 8           1  Oliver Twist (Oxford World's Classics)                   0.0
# 9           1                           Unknown Title                   0.0
#
#             ISBN
# 0     034545104X
# 1     0316650048
# 2     1582430624
# 3     0192834398
# 4  9780684800714
# 5     034545104X
# 6     0316650048
# 7     1582430624
# 8     0192834398
# 9  9780684800714
